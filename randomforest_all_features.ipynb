# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
def random_forest_pipeline_for_selected_features(datasets, target_column="Target", n_estimators=100, test_size=0.3, random_state=42, k_values=None, methods=None, output_dir="preprocessed/selected_features"):
    """
    Perform Random Forest classification on datasets with selected features.
    - datasets: List of dataset file paths (base names without method suffix).
    - target_column: Name of the target column.
    - n_estimators: Number of trees in the forest.
    - test_size: Proportion of data for testing.
    - random_state: Random state for reproducibility.
    - k_values: List of feature counts (k) used in feature selection.
    - methods: List of feature selection methods.
    - output_dir: Directory containing the selected feature files.
    """
    if k_values is None:
        k_values = [100, 200, 300, 400, 500]  # Default k values
    if methods is None:
        methods = ["std_mean", "anova", "chi2"]  # Default feature selection methods

    results = []  # Store results for comparison

    for dataset in datasets:
        dataset_name = dataset.split("/")[-1].replace("filtered_preprocessed_", "").replace(".csv", "")
        print(f"\nProcessing dataset: {dataset_name}")

        for method in methods:
            for k in k_values:
                print(f"\n  Feature selection method: {method.upper()}, k={k}")

                # Construct file path for the selected feature file
                selected_features_file = f"{output_dir}/{dataset_name}_{method}_k{k}_selected.csv"
                try:
                    # Load the dataset
                    data = pd.read_csv(selected_features_file)
                except FileNotFoundError:
                    print(f"File not found: {selected_features_file}. Skipping...")
                    continue

                # Separate features (X) and target (y)
                X = data.drop(columns=[target_column])
                y = data[target_column]

                # Split the data into training and testing sets
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=random_state)

                # Initialize and train the Random Forest classifier
                rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_state)
                rf.fit(X_train, y_train)

                # Make predictions
                y_pred = rf.predict(X_test)

                # Evaluate the model
                accuracy = accuracy_score(y_test, y_pred)
                report = classification_report(y_test, y_pred)
                confusion = confusion_matrix(y_test, y_pred)

                print("\n    Random Forest Classifier Performance:")
                print(f"    Accuracy: {accuracy}")
                print(f"\n    Classification Report:\n{report}")
                print(f"\n    Confusion Matrix:\n{confusion}")

                # Store results
                results.append({
                    "Dataset": dataset_name,
                    "Feature Method": method.upper(),
                    "Feature Count (k)": k,
                    "Accuracy": accuracy,
                    "Classification Report": report,
                    "Confusion Matrix": confusion
                })

    return results

# %%
# Example usage
if __name__ == "__main__":
    # List of datasets (base file names without method suffix)
    datasets = [
        "preprocessed/filtered_preprocessed_GSE4290",
        "preprocessed/filtered_preprocessed_GSE19804",
        "preprocessed/filtered_preprocessed_GSE27562",
        "preprocessed/filtered_preprocessed_GSE33315",
        "preprocessed/filtered_preprocessed_GSE59856"
    ]

    target_column = "Target"  # Replace with the actual target column name

    print(f"Running Random Forest classification on multiple datasets with different feature selection methods and k values...")
    results = random_forest_pipeline_for_selected_features(datasets=datasets, target_column=target_column, n_estimators=100)

    # Display summary results
    for result in results:
        print("\nSummary for Dataset:", result["Dataset"])
        print("Feature Method:", result["Feature Method"])
        print("Feature Count (k):", result["Feature Count (k)"])
        print("Accuracy:", result["Accuracy"])
# Out:
# Running Random Forest classification on multiple datasets with different feature selection methods and k values...
#
# Processing dataset: GSE4290
#
#   Feature selection method: STD_MEAN, k=100
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.660377358490566
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.67      0.96      0.79        23
#         non-tumor       1.00      0.29      0.44         7
# oligodendroglioma       0.61      0.73      0.67        15
#
#          accuracy                           0.66        53
#         macro avg       0.57      0.49      0.47        53
#      weighted avg       0.59      0.66      0.59        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 22  0  1]
#  [ 0  3  2  2]
#  [ 0  4  0 11]]
#
#   Feature selection method: STD_MEAN, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7547169811320755
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.74      0.87      0.80        23
#         non-tumor       0.86      0.86      0.86         7
# oligodendroglioma       0.74      0.93      0.82        15
#
#          accuracy                           0.75        53
#         macro avg       0.58      0.67      0.62        53
#      weighted avg       0.64      0.75      0.69        53
#
#
#     Confusion Matrix:
# [[ 0  5  0  3]
#  [ 0 20  1  2]
#  [ 0  1  6  0]
#  [ 0  1  0 14]]
#
#   Feature selection method: STD_MEAN, k=300
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.7735849056603774
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.75      0.91      0.82        23
#         non-tumor       0.83      0.71      0.77         7
# oligodendroglioma       0.79      1.00      0.88        15
#
#          accuracy                           0.77        53
#         macro avg       0.59      0.66      0.62        53
#      weighted avg       0.66      0.77      0.71        53
#
#
#     Confusion Matrix:
# [[ 0  5  0  3]
#  [ 0 21  1  1]
#  [ 0  2  5  0]
#  [ 0  0  0 15]]
#
#   Feature selection method: STD_MEAN, k=400
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.7358490566037735
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.72      0.91      0.81        23
#         non-tumor       0.86      0.86      0.86         7
# oligodendroglioma       0.71      0.80      0.75        15
#
#          accuracy                           0.74        53
#         macro avg       0.57      0.64      0.60        53
#      weighted avg       0.63      0.74      0.68        53
#
#
#     Confusion Matrix:
# [[ 0  5  0  3]
#  [ 0 21  1  1]
#  [ 0  0  6  1]
#  [ 0  3  0 12]]
#
#   Feature selection method: STD_MEAN, k=500
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.7358490566037735
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.83      0.87      0.85        23
#         non-tumor       0.64      1.00      0.78         7
# oligodendroglioma       0.67      0.80      0.73        15
#
#          accuracy                           0.74        53
#         macro avg       0.53      0.67      0.59        53
#      weighted avg       0.63      0.74      0.68        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 20  1  2]
#  [ 0  0  7  0]
#  [ 0  0  3 12]]
#
#   Feature selection method: ANOVA, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6792452830188679
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.69      0.87      0.77        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.64      0.60      0.62        15
#
#          accuracy                           0.68        53
#         macro avg       0.51      0.62      0.55        53
#      weighted avg       0.57      0.68      0.62        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 20  2  1]
#  [ 0  0  7  0]
#  [ 0  5  1  9]]
#
#   Feature selection method: ANOVA, k=200
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.6981132075471698
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.71      0.87      0.78        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.67      0.67      0.67        15
#
#          accuracy                           0.70        53
#         macro avg       0.52      0.63      0.57        53
#      weighted avg       0.59      0.70      0.64        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 20  2  1]
#  [ 0  0  7  0]
#  [ 0  4  1 10]]
#
#   Feature selection method: ANOVA, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.660377358490566
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.67      0.87      0.75        23
#         non-tumor       0.64      1.00      0.78         7
# oligodendroglioma       0.73      0.53      0.62        15
#
#          accuracy                           0.66        53
#         macro avg       0.51      0.60      0.54        53
#      weighted avg       0.58      0.66      0.60        53
#
#
#     Confusion Matrix:
# [[ 0  6  0  2]
#  [ 0 20  2  1]
#  [ 0  0  7  0]
#  [ 1  4  2  8]]
#
#   Feature selection method: ANOVA, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6981132075471698
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.70      0.91      0.79        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.75      0.60      0.67        15
#
#          accuracy                           0.70        53
#         macro avg       0.54      0.63      0.57        53
#      weighted avg       0.61      0.70      0.64        53
#
#
#     Confusion Matrix:
# [[ 0  5  0  3]
#  [ 0 21  2  0]
#  [ 0  0  7  0]
#  [ 1  4  1  9]]
#
#   Feature selection method: ANOVA, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.660377358490566
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.70      0.83      0.76        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.60      0.60      0.60        15
#
#          accuracy                           0.66        53
#         macro avg       0.50      0.61      0.55        53
#      weighted avg       0.57      0.66      0.61        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 19  2  2]
#  [ 0  0  7  0]
#  [ 1  4  1  9]]
#
#   Feature selection method: CHI2, k=100
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.6792452830188679
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.67      0.96      0.79        23
#         non-tumor       0.88      1.00      0.93         7
# oligodendroglioma       0.58      0.47      0.52        15
#
#          accuracy                           0.68        53
#         macro avg       0.53      0.61      0.56        53
#      weighted avg       0.57      0.68      0.61        53
#
#
#     Confusion Matrix:
# [[ 0  4  0  4]
#  [ 0 22  0  1]
#  [ 0  0  7  0]
#  [ 0  7  1  7]]
#
#   Feature selection method: CHI2, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6792452830188679
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.50      0.12      0.20         8
#      glioblastoma       0.70      0.83      0.76        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.64      0.60      0.62        15
#
#          accuracy                           0.68        53
#         macro avg       0.64      0.64      0.60        53
#      weighted avg       0.66      0.68      0.64        53
#
#
#     Confusion Matrix:
# [[ 1  4  0  3]
#  [ 0 19  2  2]
#  [ 0  0  7  0]
#  [ 1  4  1  9]]
#
#   Feature selection method: CHI2, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6792452830188679
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       1.00      0.12      0.22         8
#      glioblastoma       0.68      0.83      0.75        23
#         non-tumor       0.78      1.00      0.88         7
# oligodendroglioma       0.60      0.60      0.60        15
#
#          accuracy                           0.68        53
#         macro avg       0.76      0.64      0.61        53
#      weighted avg       0.72      0.68      0.64        53
#
#
#     Confusion Matrix:
# [[ 1  4  0  3]
#  [ 0 19  1  3]
#  [ 0  0  7  0]
#  [ 0  5  1  9]]
#
#   Feature selection method: CHI2, k=400
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.6792452830188679
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.65      0.87      0.74        23
#         non-tumor       0.78      1.00      0.88         7
# oligodendroglioma       0.69      0.60      0.64        15
#
#          accuracy                           0.68        53
#         macro avg       0.53      0.62      0.56        53
#      weighted avg       0.58      0.68      0.62        53
#
#
#     Confusion Matrix:
# [[ 0  6  0  2]
#  [ 0 20  1  2]
#  [ 0  0  7  0]
#  [ 0  5  1  9]]
#
#   Feature selection method: CHI2, k=500
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.660377358490566
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.00      0.00      0.00         8
#      glioblastoma       0.67      0.78      0.72        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.62      0.67      0.65        15
#
#          accuracy                           0.66        53
#         macro avg       0.50      0.61      0.55        53
#      weighted avg       0.56      0.66      0.60        53
#
#
#     Confusion Matrix:
# [[ 0  5  0  3]
#  [ 0 18  2  3]
#  [ 0  0  7  0]
#  [ 0  4  1 10]]
#
# Processing dataset: GSE19804
#
#   Feature selection method: STD_MEAN, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       1.00      0.89      0.94        18
# paired normal adjacent       0.90      1.00      0.95        18
#
#               accuracy                           0.94        36
#              macro avg       0.95      0.94      0.94        36
#           weighted avg       0.95      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[16  2]
#  [ 0 18]]
#
#   Feature selection method: STD_MEAN, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9722222222222222
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       1.00      0.94      0.97        18
# paired normal adjacent       0.95      1.00      0.97        18
#
#               accuracy                           0.97        36
#              macro avg       0.97      0.97      0.97        36
#           weighted avg       0.97      0.97      0.97        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 0 18]]
#
#   Feature selection method: STD_MEAN, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: STD_MEAN, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: STD_MEAN, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: ANOVA, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: ANOVA, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: ANOVA, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: ANOVA, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: ANOVA, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: CHI2, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: CHI2, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: CHI2, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9166666666666666
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.89      0.91        18
# paired normal adjacent       0.89      0.94      0.92        18
#
#               accuracy                           0.92        36
#              macro avg       0.92      0.92      0.92        36
#           weighted avg       0.92      0.92      0.92        36
#
#
#     Confusion Matrix:
# [[16  2]
#  [ 1 17]]
#
#   Feature selection method: CHI2, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: CHI2, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
# Processing dataset: GSE27562
#
#   Feature selection method: STD_MEAN, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6511627906976745
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.50      0.18      0.27        11
#      Ectopic       1.00      0.71      0.83         7
#    Malignant       0.55      1.00      0.71        16
#       Normal       1.00      0.56      0.71         9
#
#     accuracy                           0.65        43
#    macro avg       0.76      0.61      0.63        43
# weighted avg       0.71      0.65      0.62        43
#
#
#     Confusion Matrix:
# [[ 2  0  9  0]
#  [ 0  5  2  0]
#  [ 0  0 16  0]
#  [ 2  0  2  5]]
#
#   Feature selection method: STD_MEAN, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6511627906976745
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.00      0.00      0.00        11
#      Ectopic       1.00      1.00      1.00         7
#    Malignant       0.56      0.94      0.70        16
#       Normal       1.00      0.67      0.80         9
#
#     accuracy                           0.65        43
#    macro avg       0.64      0.65      0.62        43
# weighted avg       0.58      0.65      0.59        43
#
#
#     Confusion Matrix:
# [[ 0  0 11  0]
#  [ 0  7  0  0]
#  [ 1  0 15  0]
#  [ 2  0  1  6]]
#
#   Feature selection method: STD_MEAN, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.5813953488372093
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.00      0.00      0.00        11
#      Ectopic       0.83      0.71      0.77         7
#    Malignant       0.52      0.81      0.63        16
#       Normal       0.78      0.78      0.78         9
#
#     accuracy                           0.58        43
#    macro avg       0.53      0.58      0.55        43
# weighted avg       0.49      0.58      0.52        43
#
#
#     Confusion Matrix:
# [[ 0  1 10  0]
#  [ 0  5  2  0]
#  [ 1  0 13  2]
#  [ 2  0  0  7]]
#
#   Feature selection method: STD_MEAN, k=400
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.6976744186046512
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.00      0.00      0.00        11
#      Ectopic       0.78      1.00      0.88         7
#    Malignant       0.58      0.94      0.71        16
#       Normal       1.00      0.89      0.94         9
#
#     accuracy                           0.70        43
#    macro avg       0.59      0.71      0.63        43
# weighted avg       0.55      0.70      0.61        43
#
#
#     Confusion Matrix:
# [[ 0  1 10  0]
#  [ 0  7  0  0]
#  [ 0  1 15  0]
#  [ 0  0  1  8]]
#
#   Feature selection method: STD_MEAN, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6511627906976745
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.00      0.00      0.00        11
#      Ectopic       0.86      0.86      0.86         7
#    Malignant       0.52      0.88      0.65        16
#       Normal       1.00      0.89      0.94         9
#
#     accuracy                           0.65        43
#    macro avg       0.59      0.66      0.61        43
# weighted avg       0.54      0.65      0.58        43
#
#
#     Confusion Matrix:
# [[ 0  0 11  0]
#  [ 0  6  1  0]
#  [ 1  1 14  0]
#  [ 0  0  1  8]]
#
#   Feature selection method: ANOVA, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7209302325581395
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.40      0.18      0.25        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.65      0.81      0.72        16
#       Normal       0.90      1.00      0.95         9
#
#     accuracy                           0.72        43
#    macro avg       0.71      0.75      0.71        43
# weighted avg       0.67      0.72      0.68        43
#
#
#     Confusion Matrix:
# [[ 2  1  7  1]
#  [ 0  7  0  0]
#  [ 3  0 13  0]
#  [ 0  0  0  9]]
#
#   Feature selection method: ANOVA, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7674418604651163
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.67      0.18      0.29        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.68      0.94      0.79        16
#       Normal       0.90      1.00      0.95         9
#
#     accuracy                           0.77        43
#    macro avg       0.78      0.78      0.74        43
# weighted avg       0.76      0.77      0.72        43
#
#
#     Confusion Matrix:
# [[ 2  1  7  1]
#  [ 0  7  0  0]
#  [ 1  0 15  0]
#  [ 0  0  0  9]]
#
#   Feature selection method: ANOVA, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6511627906976745
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.25      0.09      0.13        11
#      Ectopic       0.78      1.00      0.88         7
#    Malignant       0.61      0.69      0.65        16
#       Normal       0.75      1.00      0.86         9
#
#     accuracy                           0.65        43
#    macro avg       0.60      0.69      0.63        43
# weighted avg       0.57      0.65      0.60        43
#
#
#     Confusion Matrix:
# [[ 1  1  7  2]
#  [ 0  7  0  0]
#  [ 3  1 11  1]
#  [ 0  0  0  9]]
#
#   Feature selection method: ANOVA, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6511627906976745
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.43      0.27      0.33        11
#      Ectopic       0.78      1.00      0.88         7
#    Malignant       0.59      0.62      0.61        16
#       Normal       0.80      0.89      0.84         9
#
#     accuracy                           0.65        43
#    macro avg       0.65      0.70      0.66        43
# weighted avg       0.62      0.65      0.63        43
#
#
#     Confusion Matrix:
# [[ 3  1  6  1]
#  [ 0  7  0  0]
#  [ 4  1 10  1]
#  [ 0  0  1  8]]
#
#   Feature selection method: ANOVA, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6744186046511628
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.33      0.09      0.14        11
#      Ectopic       0.78      1.00      0.88         7
#    Malignant       0.60      0.75      0.67        16
#       Normal       0.82      1.00      0.90         9
#
#     accuracy                           0.67        43
#    macro avg       0.63      0.71      0.65        43
# weighted avg       0.61      0.67      0.62        43
#
#
#     Confusion Matrix:
# [[ 1  1  8  1]
#  [ 0  7  0  0]
#  [ 2  1 12  1]
#  [ 0  0  0  9]]
#
#   Feature selection method: CHI2, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6046511627906976
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.14      0.09      0.11        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.50      0.62      0.56        16
#       Normal       1.00      0.89      0.94         9
#
#     accuracy                           0.60        43
#    macro avg       0.63      0.65      0.64        43
# weighted avg       0.57      0.60      0.58        43
#
#
#     Confusion Matrix:
# [[ 1  0 10  0]
#  [ 0  7  0  0]
#  [ 5  1 10  0]
#  [ 1  0  0  8]]
#
#   Feature selection method: CHI2, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7441860465116279
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       1.00      0.27      0.43        11
#      Ectopic       0.86      0.86      0.86         7
#    Malignant       0.62      0.94      0.75        16
#       Normal       0.89      0.89      0.89         9
#
#     accuracy                           0.74        43
#    macro avg       0.84      0.74      0.73        43
# weighted avg       0.81      0.74      0.71        43
#
#
#     Confusion Matrix:
# [[ 3  0  8  0]
#  [ 0  6  0  1]
#  [ 0  1 15  0]
#  [ 0  0  1  8]]
#
#   Feature selection method: CHI2, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7441860465116279
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.57      0.36      0.44        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.65      0.81      0.72        16
#       Normal       1.00      0.89      0.94         9
#
#     accuracy                           0.74        43
#    macro avg       0.77      0.77      0.76        43
# weighted avg       0.74      0.74      0.73        43
#
#
#     Confusion Matrix:
# [[ 4  0  7  0]
#  [ 0  7  0  0]
#  [ 2  1 13  0]
#  [ 1  0  0  8]]
#
#   Feature selection method: CHI2, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7441860465116279
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.67      0.36      0.47        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.64      0.88      0.74        16
#       Normal       1.00      0.78      0.88         9
#
#     accuracy                           0.74        43
#    macro avg       0.79      0.75      0.75        43
# weighted avg       0.76      0.74      0.73        43
#
#
#     Confusion Matrix:
# [[ 4  0  7  0]
#  [ 0  7  0  0]
#  [ 1  1 14  0]
#  [ 1  0  1  7]]
#
#   Feature selection method: CHI2, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7906976744186046
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.80      0.36      0.50        11
#      Ectopic       0.88      1.00      0.93         7
#    Malignant       0.67      0.88      0.76        16
#       Normal       1.00      1.00      1.00         9
#
#     accuracy                           0.79        43
#    macro avg       0.84      0.81      0.80        43
# weighted avg       0.80      0.79      0.77        43
#
#
#     Confusion Matrix:
# [[ 4  0  7  0]
#  [ 0  7  0  0]
#  [ 1  1 14  0]
#  [ 0  0  0  9]]
#
# Processing dataset: GSE33315
#
#   Feature selection method: STD_MEAN, k=100
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.5672514619883041
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.50      0.43      0.46        35
#    2_TCF3-PBX1       0.92      1.00      0.96        12
#   3_ETV6_RUNX1       0.43      0.40      0.41        30
#          4_MLL       1.00      0.67      0.80         9
#           5_Ph       0.00      0.00      0.00         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.43      0.65      0.52        46
#        8_T-ALL       0.88      0.88      0.88        25
#
#       accuracy                           0.57       171
#      macro avg       0.52      0.50      0.50       171
#   weighted avg       0.54      0.57      0.55       171
#
#
#     Confusion Matrix:
# [[15  0  7  0  0  0 13  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 4  0 12  0  0  0 14  0]
#  [ 0  0  0  6  0  0  1  2]
#  [ 2  0  0  0  0  0  5  0]
#  [ 2  0  1  0  0  0  4  0]
#  [ 6  1  8  0  0  0 30  1]
#  [ 1  0  0  0  0  0  2 22]]
#
#   Feature selection method: STD_MEAN, k=200
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.7368421052631579
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.66      0.66      0.66        35
#    2_TCF3-PBX1       0.92      1.00      0.96        12
#   3_ETV6_RUNX1       0.79      0.90      0.84        30
#          4_MLL       1.00      0.78      0.88         9
#           5_Ph       0.00      0.00      0.00         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.59      0.72      0.65        46
#        8_T-ALL       0.92      0.96      0.94        25
#
#       accuracy                           0.74       171
#      macro avg       0.61      0.63      0.62       171
#   weighted avg       0.68      0.74      0.71       171
#
#
#     Confusion Matrix:
# [[23  0  1  0  0  0 11  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 1  0 27  0  0  0  2  0]
#  [ 0  0  0  7  0  0  2  0]
#  [ 1  0  0  0  0  0  6  0]
#  [ 4  0  1  0  0  0  2  0]
#  [ 5  1  5  0  0  0 33  2]
#  [ 1  0  0  0  0  0  0 24]]
#
#   Feature selection method: STD_MEAN, k=300
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.7894736842105263
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.74      0.83      0.78        35
#    2_TCF3-PBX1       0.92      1.00      0.96        12
#   3_ETV6_RUNX1       0.88      0.97      0.92        30
#          4_MLL       1.00      0.67      0.80         9
#           5_Ph       0.00      0.00      0.00         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.65      0.76      0.70        46
#        8_T-ALL       0.92      0.96      0.94        25
#
#       accuracy                           0.79       171
#      macro avg       0.64      0.65      0.64       171
#   weighted avg       0.73      0.79      0.76       171
#
#
#     Confusion Matrix:
# [[29  0  0  0  0  0  6  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 1  0 29  0  0  0  0  0]
#  [ 0  0  0  6  0  0  3  0]
#  [ 1  0  0  0  0  0  6  0]
#  [ 2  0  1  0  0  0  4  0]
#  [ 5  1  3  0  0  0 35  2]
#  [ 1  0  0  0  0  0  0 24]]
#
#   Feature selection method: STD_MEAN, k=400
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiaa\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Random Forest Classifier Performance:
#     Accuracy: 0.783625730994152
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.79      0.89      0.84        35
#    2_TCF3-PBX1       0.92      1.00      0.96        12
#   3_ETV6_RUNX1       0.83      0.97      0.89        30
#          4_MLL       1.00      0.67      0.80         9
#           5_Ph       0.00      0.00      0.00         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.64      0.70      0.67        46
#        8_T-ALL       0.86      0.96      0.91        25
#
#       accuracy                           0.78       171
#      macro avg       0.63      0.65      0.63       171
#   weighted avg       0.72      0.78      0.75       171
#
#
#     Confusion Matrix:
# [[31  0  0  0  0  0  4  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 1  0 29  0  0  0  0  0]
#  [ 0  0  0  6  0  0  3  0]
#  [ 1  0  0  0  0  0  6  0]
#  [ 1  0  1  0  0  0  5  0]
#  [ 4  1  5  0  0  0 32  4]
#  [ 1  0  0  0  0  0  0 24]]
#
#   Feature selection method: STD_MEAN, k=500
# ...
#     Accuracy: 0.7393939393939394
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.45      0.48      0.47        29
#         colon cancer       0.71      0.80      0.75        15
#     esophagus cancer       0.93      0.87      0.90        15
#      healthy control       1.00      1.00      1.00        45
#         liver cancer       0.84      1.00      0.91        16
#    pancreatic cancer       0.48      0.50      0.49        30
#       stomach cancer       0.88      0.47      0.61        15
#
#             accuracy                           0.74       165
#            macro avg       0.76      0.73      0.73       165
#         weighted avg       0.75      0.74      0.74       165
#
#
#     Confusion Matrix:
# [[14  0  0  0  0 15  0]
#  [ 0 12  1  0  1  0  1]
#  [ 0  1 13  0  0  1  0]
#  [ 0  0  0 45  0  0  0]
#  [ 0  0  0  0 16  0  0]
#  [15  0  0  0  0 15  0]
#  [ 2  4  0  0  2  0  7]]
#
#   Feature selection method: ANOVA, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7575757575757576
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.53      0.66      0.58        29
#         colon cancer       0.75      0.80      0.77        15
#     esophagus cancer       0.85      0.73      0.79        15
#      healthy control       1.00      1.00      1.00        45
#         liver cancer       0.84      1.00      0.91        16
#    pancreatic cancer       0.58      0.47      0.52        30
#       stomach cancer       0.67      0.53      0.59        15
#
#             accuracy                           0.76       165
#            macro avg       0.75      0.74      0.74       165
#         weighted avg       0.76      0.76      0.75       165
#
#
#     Confusion Matrix:
# [[19  0  0  0  0 10  0]
#  [ 0 12  1  0  1  0  1]
#  [ 1  1 11  0  0  0  2]
#  [ 0  0  0 45  0  0  0]
#  [ 0  0  0  0 16  0  0]
#  [15  0  0  0  0 14  1]
#  [ 1  3  1  0  2  0  8]]
#
#   Feature selection method: ANOVA, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.7696969696969697
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.58      0.62      0.60        29
#         colon cancer       0.63      0.80      0.71        15
#     esophagus cancer       0.92      0.80      0.86        15
#      healthy control       1.00      1.00      1.00        45
#         liver cancer       0.83      0.94      0.88        16
#    pancreatic cancer       0.60      0.60      0.60        30
#       stomach cancer       0.78      0.47      0.58        15
#
#             accuracy                           0.77       165
#            macro avg       0.76      0.75      0.75       165
#         weighted avg       0.78      0.77      0.77       165
#
#
#     Confusion Matrix:
# [[18  0  0  0  0 11  0]
#  [ 0 12  1  0  1  0  1]
#  [ 1  2 12  0  0  0  0]
#  [ 0  0  0 45  0  0  0]
#  [ 0  0  0  0 15  0  1]
#  [11  1  0  0  0 18  0]
#  [ 1  4  0  0  2  1  7]]
#
#   Feature selection method: CHI2, k=100
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.42424242424242425
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.33      0.21      0.26        29
#         colon cancer       1.00      0.13      0.24        15
#     esophagus cancer       0.56      0.93      0.70        15
#      healthy control       0.42      0.67      0.52        45
#         liver cancer       0.50      0.44      0.47        16
#    pancreatic cancer       0.36      0.33      0.34        30
#       stomach cancer       0.14      0.07      0.09        15
#
#             accuracy                           0.42       165
#            macro avg       0.47      0.40      0.37       165
#         weighted avg       0.44      0.42      0.39       165
#
#
#     Confusion Matrix:
# [[ 6  0  1 15  0  6  1]
#  [ 1  2  0  7  2  1  2]
#  [ 0  0 14  1  0  0  0]
#  [ 6  0  3 30  0  5  1]
#  [ 2  0  2  1  7  2  2]
#  [ 3  0  3 11  3 10  0]
#  [ 0  0  2  6  2  4  1]]
#
#   Feature selection method: CHI2, k=200
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.4909090909090909
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.50      0.28      0.36        29
#         colon cancer       0.60      0.20      0.30        15
#     esophagus cancer       0.62      0.67      0.65        15
#      healthy control       0.46      0.82      0.59        45
#         liver cancer       0.56      0.56      0.56        16
#    pancreatic cancer       0.50      0.43      0.46        30
#       stomach cancer       0.20      0.07      0.10        15
#
#             accuracy                           0.49       165
#            macro avg       0.49      0.43      0.43       165
#         weighted avg       0.49      0.49      0.46       165
#
#
#     Confusion Matrix:
# [[ 8  1  0 16  0  3  1]
#  [ 0  3  0  6  1  3  2]
#  [ 0  0 10  4  0  1  0]
#  [ 2  0  2 37  0  3  1]
#  [ 3  0  1  1  9  2  0]
#  [ 3  0  1  9  4 13  0]
#  [ 0  1  2  8  2  1  1]]
#
#   Feature selection method: CHI2, k=300
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.5757575757575758
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.45      0.31      0.37        29
#         colon cancer       0.60      0.20      0.30        15
#     esophagus cancer       0.73      0.73      0.73        15
#      healthy control       0.64      0.93      0.76        45
#         liver cancer       0.57      0.75      0.65        16
#    pancreatic cancer       0.50      0.53      0.52        30
#       stomach cancer       0.33      0.13      0.19        15
#
#             accuracy                           0.58       165
#            macro avg       0.55      0.51      0.50       165
#         weighted avg       0.55      0.58      0.54       165
#
#
#     Confusion Matrix:
# [[ 9  0  1  9  0  9  1]
#  [ 2  3  0  4  2  1  3]
#  [ 1  0 11  0  1  2  0]
#  [ 3  0  0 42  0  0  0]
#  [ 2  0  1  1 12  0  0]
#  [ 2  1  0  6  5 16  0]
#  [ 1  1  2  4  1  4  2]]
#
#   Feature selection method: CHI2, k=400
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.6
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.43      0.41      0.42        29
#         colon cancer       0.40      0.13      0.20        15
#     esophagus cancer       0.88      0.47      0.61        15
#      healthy control       0.72      0.96      0.82        45
#         liver cancer       0.67      0.75      0.71        16
#    pancreatic cancer       0.51      0.60      0.55        30
#       stomach cancer       0.45      0.33      0.38        15
#
#             accuracy                           0.60       165
#            macro avg       0.58      0.52      0.53       165
#         weighted avg       0.59      0.60      0.58       165
#
#
#     Confusion Matrix:
# [[12  0  0  6  1 10  0]
#  [ 4  2  0  1  1  2  5]
#  [ 0  1  7  3  2  1  1]
#  [ 2  0  0 43  0  0  0]
#  [ 1  0  0  0 12  3  0]
#  [ 8  0  0  3  1 18  0]
#  [ 1  2  1  4  1  1  5]]
#
#   Feature selection method: CHI2, k=500
#
#     Random Forest Classifier Performance:
#     Accuracy: 0.5757575757575758
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.36      0.28      0.31        29
#         colon cancer       0.60      0.20      0.30        15
#     esophagus cancer       0.80      0.53      0.64        15
#      healthy control       0.67      0.96      0.79        45
#         liver cancer       0.57      0.75      0.65        16
#    pancreatic cancer       0.47      0.50      0.48        30
#       stomach cancer       0.55      0.40      0.46        15
#
#             accuracy                           0.58       165
#            macro avg       0.57      0.52      0.52       165
#         weighted avg       0.56      0.58      0.55       165
#
#
#     Confusion Matrix:
# [[ 8  0  0  8  1 12  0]
#  [ 0  3  0  3  3  2  4]
#  [ 2  0  8  3  1  0  1]
#  [ 2  0  0 43  0  0  0]
#  [ 3  0  0  0 12  1  0]
#  [ 7  0  0  6  2 15  0]
#  [ 0  2  2  1  2  2  6]]
#
# Summary for Dataset: GSE4290
# Feature Method: STD_MEAN
# Feature Count (k): 100
# Accuracy: 0.660377358490566
#
# Summary for Dataset: GSE4290
# Feature Method: STD_MEAN
# Feature Count (k): 200
# Accuracy: 0.7547169811320755
#
# Summary for Dataset: GSE4290
# Feature Method: STD_MEAN
# Feature Count (k): 300
# Accuracy: 0.7735849056603774
#
# Summary for Dataset: GSE4290
# Feature Method: STD_MEAN
# Feature Count (k): 400
# Accuracy: 0.7358490566037735
#
# Summary for Dataset: GSE4290
# Feature Method: STD_MEAN
# Feature Count (k): 500
# Accuracy: 0.7358490566037735
#
# Summary for Dataset: GSE4290
# Feature Method: ANOVA
# Feature Count (k): 100
# Accuracy: 0.6792452830188679
#
# Summary for Dataset: GSE4290
# Feature Method: ANOVA
# Feature Count (k): 200
# Accuracy: 0.6981132075471698
#
# Summary for Dataset: GSE4290
# Feature Method: ANOVA
# Feature Count (k): 300
# Accuracy: 0.660377358490566
#
# Summary for Dataset: GSE4290
# Feature Method: ANOVA
# Feature Count (k): 400
# Accuracy: 0.6981132075471698
#
# Summary for Dataset: GSE4290
# Feature Method: ANOVA
# Feature Count (k): 500
# Accuracy: 0.660377358490566
#
# Summary for Dataset: GSE4290
# Feature Method: CHI2
# Feature Count (k): 100
# Accuracy: 0.6792452830188679
#
# Summary for Dataset: GSE4290
# Feature Method: CHI2
# Feature Count (k): 200
# Accuracy: 0.6792452830188679
#
# Summary for Dataset: GSE4290
# Feature Method: CHI2
# Feature Count (k): 300
# Accuracy: 0.6792452830188679
#
# Summary for Dataset: GSE4290
# Feature Method: CHI2
# Feature Count (k): 400
# Accuracy: 0.6792452830188679
#
# Summary for Dataset: GSE4290
# Feature Method: CHI2
# Feature Count (k): 500
# Accuracy: 0.660377358490566
#
# Summary for Dataset: GSE19804
# Feature Method: STD_MEAN
# Feature Count (k): 100
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: STD_MEAN
# Feature Count (k): 200
# Accuracy: 0.9722222222222222
#
# Summary for Dataset: GSE19804
# Feature Method: STD_MEAN
# Feature Count (k): 300
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: STD_MEAN
# Feature Count (k): 400
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: STD_MEAN
# Feature Count (k): 500
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: ANOVA
# Feature Count (k): 100
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: ANOVA
# Feature Count (k): 200
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: ANOVA
# Feature Count (k): 300
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: ANOVA
# Feature Count (k): 400
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: ANOVA
# Feature Count (k): 500
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: CHI2
# Feature Count (k): 100
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: CHI2
# Feature Count (k): 200
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: CHI2
# Feature Count (k): 300
# Accuracy: 0.9166666666666666
#
# Summary for Dataset: GSE19804
# Feature Method: CHI2
# Feature Count (k): 400
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE19804
# Feature Method: CHI2
# Feature Count (k): 500
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: GSE27562
# Feature Method: STD_MEAN
# Feature Count (k): 100
# Accuracy: 0.6511627906976745
#
# Summary for Dataset: GSE27562
# Feature Method: STD_MEAN
# Feature Count (k): 200
# Accuracy: 0.6511627906976745
#
# Summary for Dataset: GSE27562
# Feature Method: STD_MEAN
# Feature Count (k): 300
# Accuracy: 0.5813953488372093
#
# Summary for Dataset: GSE27562
# Feature Method: STD_MEAN
# Feature Count (k): 400
# Accuracy: 0.6976744186046512
#
# Summary for Dataset: GSE27562
# Feature Method: STD_MEAN
# Feature Count (k): 500
# Accuracy: 0.6511627906976745
#
# Summary for Dataset: GSE27562
# Feature Method: ANOVA
# Feature Count (k): 100
# Accuracy: 0.7209302325581395
#
# Summary for Dataset: GSE27562
# Feature Method: ANOVA
# Feature Count (k): 200
# Accuracy: 0.7674418604651163
#
# Summary for Dataset: GSE27562
# Feature Method: ANOVA
# Feature Count (k): 300
# Accuracy: 0.6511627906976745
#
# Summary for Dataset: GSE27562
# Feature Method: ANOVA
# Feature Count (k): 400
# Accuracy: 0.6511627906976745
#
# Summary for Dataset: GSE27562
# Feature Method: ANOVA
# Feature Count (k): 500
# Accuracy: 0.6744186046511628
#
# Summary for Dataset: GSE27562
# Feature Method: CHI2
# Feature Count (k): 100
# Accuracy: 0.6046511627906976
#
# Summary for Dataset: GSE27562
# Feature Method: CHI2
# Feature Count (k): 200
# Accuracy: 0.7441860465116279
#
# Summary for Dataset: GSE27562
# Feature Method: CHI2
# Feature Count (k): 300
# Accuracy: 0.7441860465116279
#
# Summary for Dataset: GSE27562
# Feature Method: CHI2
# Feature Count (k): 400
# Accuracy: 0.7441860465116279
#
# Summary for Dataset: GSE27562
# Feature Method: CHI2
# Feature Count (k): 500
# Accuracy: 0.7906976744186046
#
# Summary for Dataset: GSE33315
# Feature Method: STD_MEAN
# Feature Count (k): 100
# Accuracy: 0.5672514619883041
#
# Summary for Dataset: GSE33315
# Feature Method: STD_MEAN
# Feature Count (k): 200
# Accuracy: 0.7368421052631579
#
# Summary for Dataset: GSE33315
# Feature Method: STD_MEAN
# Feature Count (k): 300
# Accuracy: 0.7894736842105263
#
# Summary for Dataset: GSE33315
# Feature Method: STD_MEAN
# Feature Count (k): 400
# Accuracy: 0.783625730994152
#
# Summary for Dataset: GSE33315
# Feature Method: STD_MEAN
# Feature Count (k): 500
# Accuracy: 0.8070175438596491
#
# Summary for Dataset: GSE33315
# Feature Method: ANOVA
# Feature Count (k): 100
# Accuracy: 0.7894736842105263
#
# Summary for Dataset: GSE33315
# Feature Method: ANOVA
# Feature Count (k): 200
# Accuracy: 0.8070175438596491
#
# Summary for Dataset: GSE33315
# Feature Method: ANOVA
# Feature Count (k): 300
# Accuracy: 0.8011695906432749
#
# Summary for Dataset: GSE33315
# Feature Method: ANOVA
# Feature Count (k): 400
# Accuracy: 0.8187134502923976
#
# Summary for Dataset: GSE33315
# Feature Method: ANOVA
# Feature Count (k): 500
# Accuracy: 0.8128654970760234
#
# Summary for Dataset: GSE33315
# Feature Method: CHI2
# Feature Count (k): 100
# Accuracy: 0.6549707602339181
#
# Summary for Dataset: GSE33315
# Feature Method: CHI2
# Feature Count (k): 200
# Accuracy: 0.7134502923976608
#
# Summary for Dataset: GSE33315
# Feature Method: CHI2
# Feature Count (k): 300
# Accuracy: 0.7485380116959064
#
# Summary for Dataset: GSE33315
# Feature Method: CHI2
# Feature Count (k): 400
# Accuracy: 0.7426900584795322
#
# Summary for Dataset: GSE33315
# Feature Method: CHI2
# Feature Count (k): 500
# Accuracy: 0.7602339181286549
#
# Summary for Dataset: GSE59856
# Feature Method: STD_MEAN
# Feature Count (k): 100
# Accuracy: 0.23030303030303031
#
# Summary for Dataset: GSE59856
# Feature Method: STD_MEAN
# Feature Count (k): 200
# Accuracy: 0.22424242424242424
#
# Summary for Dataset: GSE59856
# Feature Method: STD_MEAN
# Feature Count (k): 300
# Accuracy: 0.18787878787878787
#
# Summary for Dataset: GSE59856
# Feature Method: STD_MEAN
# Feature Count (k): 400
# Accuracy: 0.22424242424242424
#
# Summary for Dataset: GSE59856
# Feature Method: STD_MEAN
# Feature Count (k): 500
# Accuracy: 0.24848484848484848
#
# Summary for Dataset: GSE59856
# Feature Method: ANOVA
# Feature Count (k): 100
# Accuracy: 0.793939393939394
#
# Summary for Dataset: GSE59856
# Feature Method: ANOVA
# Feature Count (k): 200
# Accuracy: 0.8
#
# Summary for Dataset: GSE59856
# Feature Method: ANOVA
# Feature Count (k): 300
# Accuracy: 0.7393939393939394
#
# Summary for Dataset: GSE59856
# Feature Method: ANOVA
# Feature Count (k): 400
# Accuracy: 0.7575757575757576
#
# Summary for Dataset: GSE59856
# Feature Method: ANOVA
# Feature Count (k): 500
# Accuracy: 0.7696969696969697
#
# Summary for Dataset: GSE59856
# Feature Method: CHI2
# Feature Count (k): 100
# Accuracy: 0.42424242424242425
#
# Summary for Dataset: GSE59856
# Feature Method: CHI2
# Feature Count (k): 200
# Accuracy: 0.4909090909090909
#
# Summary for Dataset: GSE59856
# Feature Method: CHI2
# Feature Count (k): 300
# Accuracy: 0.5757575757575758
#
# Summary for Dataset: GSE59856
# Feature Method: CHI2
# Feature Count (k): 400
# Accuracy: 0.6
#
# Summary for Dataset: GSE59856
# Feature Method: CHI2
# Feature Count (k): 500
# Accuracy: 0.5757575757575758
