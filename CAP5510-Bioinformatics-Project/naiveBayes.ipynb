# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
def naive_bayes_pipeline_for_multiple_datasets(datasets, target_column="Target", test_size=0.3, random_state=42):
    """
    Perform Naive Bayes classification on multiple datasets and feature selection methods.
    - datasets: List of dataset file paths (base names without method suffix).
    - target_column: Name of the target column.
    - test_size: Proportion of data for testing.
    - random_state: Random state for reproducibility.
    """
    feature_methods = [
        "_std_mean_selected.csv",
        "_anova_selected.csv",
        "_chi2_selected.csv"
    ]

    results = []  # Store results for comparison

    for dataset in datasets:
        print(f"\nProcessing dataset: {dataset}")
        for method in feature_methods:
            print(f"\n  Feature selection method: {method.replace('_selected.csv', '').upper()}")

            # Load the dataset
            selected_features_file = dataset + method
            data = pd.read_csv(selected_features_file)

            # Separate features (X) and target (y)
            X = data.drop(columns=[data.columns[0], target_column])  # Exclude Sample IDs and target
            y = data[target_column]

            # Split the data into training and testing sets
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=random_state)

            # Standardize the features (Naive Bayes does not require scaling but it's helpful for numerical stability)
            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

            # Initialize and train the Naive Bayes classifier
            nb = GaussianNB()
            nb.fit(X_train, y_train)

            # Make predictions
            y_pred = nb.predict(X_test)

            # Evaluate the model
            accuracy = accuracy_score(y_test, y_pred)
            report = classification_report(y_test, y_pred)
            confusion = confusion_matrix(y_test, y_pred)

            print("\n    Naive Bayes Classifier Performance:")
            print(f"    Accuracy: {accuracy}")
            print(f"\n    Classification Report:\n{report}")
            print(f"\n    Confusion Matrix:\n{confusion}")

            # Store results
            results.append({
                "Dataset": dataset,
                "Feature Method": method.replace("_selected.csv", "").upper(),
                "Accuracy": accuracy,
                "Classification Report": report,
                "Confusion Matrix": confusion
            })

    return results

# %%
# Example usage
if __name__ == "__main__":
    # List of datasets (base file names without method suffix)
    datasets = [
        "preprocessed/filtered_preprocessed_GSE4290",
        "preprocessed/filtered_preprocessed_GSE19804",
        "preprocessed/filtered_preprocessed_GSE27562",
        "preprocessed/filtered_preprocessed_GSE33315",
        "preprocessed/filtered_preprocessed_GSE59856"
    ]

    target_column = "Target"  # Replace with the actual target column name

    print(f"Running Naive Bayes classification on multiple datasets with different feature selection methods...")
    results = naive_bayes_pipeline_for_multiple_datasets(datasets=datasets, target_column=target_column)

    # Display summary results
    for result in results:
        print("\nSummary for Dataset:", result["Dataset"])
        print("Feature Method:", result["Feature Method"])
        print("Accuracy:", result["Accuracy"])
# Out:
# Running Naive Bayes classification on multiple datasets with different feature selection methods...
#
# Processing dataset: preprocessed/filtered_preprocessed_GSE4290
#
#   Feature selection method: _STD_MEAN
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.4339622641509434
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.25      0.25      0.25         8
#      glioblastoma       0.67      0.26      0.38        23
#         non-tumor       0.36      0.71      0.48         7
# oligodendroglioma       0.45      0.67      0.54        15
#
#          accuracy                           0.43        53
#         macro avg       0.43      0.47      0.41        53
#      weighted avg       0.50      0.43      0.42        53
#
#
#     Confusion Matrix:
# [[ 2  2  3  1]
#  [ 6  6  1 10]
#  [ 0  1  5  1]
#  [ 0  0  5 10]]
#
#   Feature selection method: _ANOVA
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.5094339622641509
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.25      0.12      0.17         8
#      glioblastoma       0.54      0.83      0.66        23
#         non-tumor       0.58      1.00      0.74         7
# oligodendroglioma       0.00      0.00      0.00        15
#
#          accuracy                           0.51        53
#         macro avg       0.34      0.49      0.39        53
#      weighted avg       0.35      0.51      0.41        53
#
#
#     Confusion Matrix:
# [[ 1  6  0  1]
#  [ 1 19  2  1]
#  [ 0  0  7  0]
#  [ 2 10  3  0]]
#
#   Feature selection method: _CHI2
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.5849056603773585
#
#     Classification Report:
#                    precision    recall  f1-score   support
#
#       astrocytoma       0.17      0.12      0.14         8
#      glioblastoma       0.61      0.83      0.70        23
#         non-tumor       0.70      1.00      0.82         7
# oligodendroglioma       0.67      0.27      0.38        15
#
#          accuracy                           0.58        53
#         macro avg       0.54      0.55      0.51        53
#      weighted avg       0.57      0.58      0.54        53
#
#
#     Confusion Matrix:
# [[ 1  5  0  2]
#  [ 2 19  2  0]
#  [ 0  0  7  0]
#  [ 3  7  1  4]]
#
# Processing dataset: preprocessed/filtered_preprocessed_GSE19804
#
#   Feature selection method: _STD_MEAN
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.8611111111111112
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.88      0.83      0.86        18
# paired normal adjacent       0.84      0.89      0.86        18
#
#               accuracy                           0.86        36
#              macro avg       0.86      0.86      0.86        36
#           weighted avg       0.86      0.86      0.86        36
#
#
#     Confusion Matrix:
# [[15  3]
#  [ 2 16]]
#
#   Feature selection method: _ANOVA
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.9444444444444444
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.94      0.94        18
# paired normal adjacent       0.94      0.94      0.94        18
#
#               accuracy                           0.94        36
#              macro avg       0.94      0.94      0.94        36
#           weighted avg       0.94      0.94      0.94        36
#
#
#     Confusion Matrix:
# [[17  1]
#  [ 1 17]]
#
#   Feature selection method: _CHI2
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.9166666666666666
#
#     Classification Report:
#                         precision    recall  f1-score   support
#
#            lung cancer       0.94      0.89      0.91        18
# paired normal adjacent       0.89      0.94      0.92        18
#
#               accuracy                           0.92        36
#              macro avg       0.92      0.92      0.92        36
#           weighted avg       0.92      0.92      0.92        36
#
#
#     Confusion Matrix:
# [[16  2]
#  [ 1 17]]
#
# Processing dataset: preprocessed/filtered_preprocessed_GSE27562
#
#   Feature selection method: _STD_MEAN
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.4883720930232558
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.29      0.45      0.36        11
#      Ectopic       0.71      0.71      0.71         7
#    Malignant       0.50      0.25      0.33        16
#       Normal       0.64      0.78      0.70         9
#
#     accuracy                           0.49        43
#    macro avg       0.54      0.55      0.53        43
# weighted avg       0.51      0.49      0.48        43
#
#
#     Confusion Matrix:
# [[5 2 3 1]
#  [2 5 0 0]
#  [9 0 4 3]
#  [1 0 1 7]]
#
#   Feature selection method: _ANOVA
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.6744186046511628
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.44      0.36      0.40        11
#      Ectopic       0.78      1.00      0.88         7
#    Malignant       0.64      0.56      0.60        16
#       Normal       0.82      1.00      0.90         9
#
#     accuracy                           0.67        43
#    macro avg       0.67      0.73      0.69        43
# weighted avg       0.65      0.67      0.66        43
#
#
#     Confusion Matrix:
# [[4 1 5 1]
#  [0 7 0 0]
#  [5 1 9 1]
#  [0 0 0 9]]
#
#   Feature selection method: _CHI2
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.5116279069767442
#
#     Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.14      0.09      0.11        11
#      Ectopic       0.70      1.00      0.82         7
#    Malignant       0.48      0.69      0.56        16
#       Normal       1.00      0.33      0.50         9
#
#     accuracy                           0.51        43
#    macro avg       0.58      0.53      0.50        43
# weighted avg       0.54      0.51      0.48        43
#
#
#     Confusion Matrix:
# [[ 1  1  9  0]
#  [ 0  7  0  0]
#  [ 3  2 11  0]
#  [ 3  0  3  3]]
#
# Processing dataset: preprocessed/filtered_preprocessed_GSE33315
#
#   Feature selection method: _STD_MEAN
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.4093567251461988
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.38      0.17      0.24        35
#    2_TCF3-PBX1       0.63      1.00      0.77        12
#   3_ETV6_RUNX1       0.29      0.27      0.28        30
#          4_MLL       0.67      0.67      0.67         9
#           5_Ph       0.22      0.71      0.33         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.61      0.24      0.34        46
#        8_T-ALL       0.81      0.88      0.85        25
#
#       accuracy                           0.41       171
#      macro avg       0.45      0.49      0.43       171
#   weighted avg       0.50      0.41      0.42       171
#
#
#     Confusion Matrix:
# [[ 6  2 11  1  3 12  0  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 2  0  8  0  6 12  2  0]
#  [ 0  1  0  6  0  0  1  1]
#  [ 1  0  1  0  5  0  0  0]
#  [ 1  0  2  0  2  0  2  0]
#  [ 5  4  6  2  7  7 11  4]
#  [ 1  0  0  0  0  0  2 22]]
#
#   Feature selection method: _ANOVA
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.695906432748538
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.74      0.80      0.77        35
#    2_TCF3-PBX1       0.92      1.00      0.96        12
#   3_ETV6_RUNX1       0.85      0.93      0.89        30
#          4_MLL       0.62      0.56      0.59         9
#           5_Ph       0.21      0.57      0.31         7
#         6_Hypo       0.00      0.00      0.00         7
#        7_Other       0.69      0.43      0.53        46
#        8_T-ALL       0.88      0.88      0.88        25
#
#       accuracy                           0.70       171
#      macro avg       0.61      0.65      0.62       171
#   weighted avg       0.72      0.70      0.70       171
#
#
#     Confusion Matrix:
# [[28  0  0  0  6  1  0  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 0  0 28  0  0  0  1  1]
#  [ 0  0  0  5  0  0  4  0]
#  [ 1  0  0  0  4  1  1  0]
#  [ 1  0  1  0  2  0  3  0]
#  [ 7  1  4  1  7  4 20  2]
#  [ 1  0  0  2  0  0  0 22]]
#
#   Feature selection method: _CHI2
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.5789473684210527
#
#     Classification Report:
#                 precision    recall  f1-score   support
#
# 1_Hyperdiploid       0.52      0.43      0.47        35
#    2_TCF3-PBX1       0.86      1.00      0.92        12
#   3_ETV6_RUNX1       0.56      0.80      0.66        30
#          4_MLL       0.64      1.00      0.78         9
#           5_Ph       0.11      0.29      0.16         7
#         6_Hypo       0.10      0.14      0.12         7
#        7_Other       0.67      0.26      0.38        46
#        8_T-ALL       0.96      0.96      0.96        25
#
#       accuracy                           0.58       171
#      macro avg       0.55      0.61      0.56       171
#   weighted avg       0.63      0.58      0.57       171
#
#
#     Confusion Matrix:
# [[15  1  7  0  4  5  3  0]
#  [ 0 12  0  0  0  0  0  0]
#  [ 3  0 24  0  1  1  1  0]
#  [ 0  0  0  9  0  0  0  0]
#  [ 2  0  0  0  2  2  1  0]
#  [ 1  0  1  1  2  1  1  0]
#  [ 8  1 11  4  8  1 12  1]
#  [ 0  0  0  0  1  0  0 24]]
#
# Processing dataset: preprocessed/filtered_preprocessed_GSE59856
#
#   Feature selection method: _STD_MEAN
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.15757575757575756
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.11      0.03      0.05        29
#         colon cancer       0.13      0.20      0.16        15
#     esophagus cancer       0.18      0.13      0.15        15
#      healthy control       0.20      0.04      0.07        45
#         liver cancer       0.12      0.62      0.20        16
#    pancreatic cancer       0.37      0.23      0.29        30
#       stomach cancer       0.14      0.07      0.09        15
#
#             accuracy                           0.16       165
#            macro avg       0.18      0.19      0.14       165
#         weighted avg       0.19      0.16      0.14       165
#
#
#     Confusion Matrix:
# [[ 1  3  3  5 16  1  0]
#  [ 1  3  1  1  5  2  2]
#  [ 1  0  2  0 11  1  0]
#  [ 2  8  4  2 21  4  4]
#  [ 0  3  0  1 10  2  0]
#  [ 3  5  1  1 13  7  0]
#  [ 1  1  0  0 10  2  1]]
#
#   Feature selection method: _ANOVA
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.593939393939394
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.32      0.34      0.33        29
#         colon cancer       0.75      0.60      0.67        15
#     esophagus cancer       0.62      0.67      0.65        15
#      healthy control       1.00      0.93      0.97        45
#         liver cancer       0.43      0.38      0.40        16
#    pancreatic cancer       0.41      0.43      0.42        30
#       stomach cancer       0.44      0.53      0.48        15
#
#             accuracy                           0.59       165
#            macro avg       0.57      0.56      0.56       165
#         weighted avg       0.61      0.59      0.60       165
#
#
#     Confusion Matrix:
# [[10  0  0  0  1 18  0]
#  [ 1  9  1  0  1  0  3]
#  [ 0  0 10  0  3  1  1]
#  [ 3  0  0 42  0  0  0]
#  [ 0  1  3  0  6  0  6]
#  [16  1  0  0  0 13  0]
#  [ 1  1  2  0  3  0  8]]
#
#   Feature selection method: _CHI2
#
#     Naive Bayes Classifier Performance:
#     Accuracy: 0.23030303030303031
#
#     Classification Report:
#                       precision    recall  f1-score   support
#
# biliary tract cancer       0.58      0.24      0.34        29
#         colon cancer       0.18      0.27      0.22        15
#     esophagus cancer       0.17      0.20      0.18        15
#      healthy control       0.29      0.09      0.14        45
#         liver cancer       0.15      0.56      0.23        16
#    pancreatic cancer       0.33      0.23      0.27        30
#       stomach cancer       0.25      0.27      0.26        15
#
#             accuracy                           0.23       165
#            macro avg       0.28      0.27      0.23       165
#         weighted avg       0.31      0.23      0.23       165
#
#
#     Confusion Matrix:
# [[ 7  3  2  3  6  4  4]
#  [ 0  4  3  3  3  1  1]
#  [ 2  1  3  1  6  1  1]
#  [ 2  4  6  4 20  6  3]
#  [ 0  4  1  0  9  1  1]
#  [ 1  5  2  2 11  7  2]
#  [ 0  1  1  1  7  1  4]]
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE4290
# Feature Method: _STD_MEAN
# Accuracy: 0.4339622641509434
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE4290
# Feature Method: _ANOVA
# Accuracy: 0.5094339622641509
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE4290
# Feature Method: _CHI2
# Accuracy: 0.5849056603773585
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE19804
# Feature Method: _STD_MEAN
# Accuracy: 0.8611111111111112
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE19804
# Feature Method: _ANOVA
# Accuracy: 0.9444444444444444
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE19804
# Feature Method: _CHI2
# Accuracy: 0.9166666666666666
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE27562
# Feature Method: _STD_MEAN
# Accuracy: 0.4883720930232558
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE27562
# Feature Method: _ANOVA
# Accuracy: 0.6744186046511628
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE27562
# Feature Method: _CHI2
# Accuracy: 0.5116279069767442
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE33315
# Feature Method: _STD_MEAN
# Accuracy: 0.4093567251461988
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE33315
# Feature Method: _ANOVA
# Accuracy: 0.695906432748538
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE33315
# Feature Method: _CHI2
# Accuracy: 0.5789473684210527
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE59856
# Feature Method: _STD_MEAN
# Accuracy: 0.15757575757575756
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE59856
# Feature Method: _ANOVA
# Accuracy: 0.593939393939394
#
# Summary for Dataset: preprocessed/filtered_preprocessed_GSE59856
# Feature Method: _CHI2
# Accuracy: 0.23030303030303031
